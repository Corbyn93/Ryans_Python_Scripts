# %%
import csv 
import numpy as np 
import matplotlib.pyplot as plot

# %matplotlib notebook

# %%
folderID = 'I:\\Science\\Physics-Nanobiophotonics\\Group\\User Data\\STED AO Calib and Setup\\'
date = '20191002'
fileID = folderID + date + '\\DSO00004.csv'
data = []

# %%
with open(fileID, 'r') as csvData:
    csvReader = csv.reader(csvData)
    next(csvData)
    next(csvData)
    for row in csvReader:
        data.append(row)

# %%
time = []
volt = []
for i in range(len(data)):
    time.append(float(data[i][3]))
    volt.append(float(data[i][4]))

# %%
plot.plot(time, volt)
# Out:
# <img src="data:image/png;base64,..." width="640">
